# %%
from google.colab import drive
drive.mount('/content/drive')
# !cp -r /content/drive/MyDrive/5th_fall_sem_22_23/n_body_simulation/cpu_parallel_nlogn_folder/* ./
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls -la
# Out:
# total 63976
# drwxr-xr-x 1 root root     4096 Nov 18 19:16 .
# drwxr-xr-x 1 root root     4096 Nov 18 13:47 ..
# -rw------- 1 root root     9823 Nov 18 16:02 BarnzNhutt.cpp
# -rw------- 1 root root     8352 Nov 18 16:02 Bhtree.cpp
# -rwxr-xr-x 1 root root      184 Nov 18 16:02 build.bash
# drwxr-xr-x 4 root root     4096 Nov 16 14:34 .config
# -rw------- 1 root root     2056 Nov 18 16:02 Constants.h
# -rwxr-xr-x 1 root root       55 Nov 18 16:02 createVideo.bash
# -rwxr-xr-x 1 root root       16 Nov 18 16:02 deleteImgs.bash
# drwx------ 6 root root     4096 Nov 18 14:50 drive
# drwx------ 2 root root     4096 Nov 18 14:50 examples
# drwx------ 2 root root   532480 Nov 18 19:07 images
# -rw------- 1 root root     1549 Nov 18 16:02 Octant.cpp
# -rw-r--r-- 1 root root 64777317 Nov 18 19:28 result.mp4
# -rwxr-xr-x 1 root root    49728 Nov 18 16:02 run
# -rw-r--r-- 1 root root    70960 Nov 18 16:02 run.o
# drwxr-xr-x 1 root root     4096 Nov 16 14:35 sample_data

# %%
# !chmod 755 build.bash
# !chmod 755 createVideo.bash
# !chmod 755 deleteImgs.bash

# %%
! ./build.bash
# Out:
# ++ opt='-O3 -march=native -mtune=native'
# ++ g++ -std=c++11 -Wall -Wextra -O3 -march=native -mtune=native BarnzNhutt.cpp -c -o run.o -fopenmp
# ++ g++ run.o -o run -fopenmp

# %%
# !time ./run
# Out:
# Streaming output truncated to the last 5000 lines.
# Calculating particle interactions...
# Updating particle positions...
# Star x accel: 6.98434  Star y accel: -10.2265
# Mass below: 1.95776e+30 Mass Above: 1.04214e+30
# Ratio: 1.87859
# Writing frame 15644
# Clearing Pixels...
# Rendering Particles...
# Writing frame to file...
# -------Done------- timestep: 15643
#
# Beginning timestep: 15644
# Calculating Force from star...
# Building Octree...
# Calculating particle interactions...
# Updating particle positions...
# Star x accel: 1.62978  Star y accel: -2.88708
# Mass below: 1.95786e+30 Mass Above: 1.04205e+30
# Ratio: 1.87884
# Writing frame 15645
# Clearing Pixels...
# Rendering Particles...
# Writing frame to file...
# -------Done------- timestep: 15644
#
# Beginning timestep: 15645
# Calculating Force from star...
# Building Octree...
# Calculating particle interactions...
# Updating particle positions...
# Star x accel: 3.11445  Star y accel: 0.654184
# ...

# %%
! ./createVideo.bash
# Out:
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %%
# ! ./deleteImgs.bash
